# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize']=[20,10]

# %%
pd.set_option('display.float_format', lambda x:'%.2f' % x)

# %%
df=pd.read_csv(r".\Travel - Copy.csv")
df
# Out:
#       CustomerID  ProdTaken  Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41t     Self Enquiry         3             6.00
# 1         200001          0   49  Company Invited         1            14.00
# 2         200002          1   37     Self Enquiry         1             8.00
# 3         200003          0   33  Company Invited         1             9.00
# 4         200004          0  NaN     Self Enquiry         1             8.00
# ...          ...        ...  ...              ...       ...              ...
# 4883      204883          1   49     Self Enquiry         3             9.00
# 4884      204884          1   28  Company Invited         1            31.00
# 4885      204885          1   52     Self Enquiry         3            17.00
# 4886      204886          1   19     Self Enquiry         3            16.00
# 4887      204887          1   36     Self Enquiry         1            14.00
#
#           Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0           Salaried  Female                       3               3.00
# 1           Salaried    Male                       3               4.00
# 2        Free Lancer    Male                       3               4.00
# 3           Salaried  Female                       2               3.00
# 4     Small Business    Male                       2               3.00
# ...              ...     ...                     ...                ...
# 4883  Small Business    Male                       3               5.00
# 4884        Salaried    Male                       4               5.00
# 4885        Salaried  Female                       4               4.00
# 4886  Small Business    Male                       3               4.00
# 4887        Salaried    Male                       4               4.00
#
#      ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 0            Deluxe                   3.00        Single           1.00
# 1            Deluxe                   4.00      Divorced           2.00
# 2             Basic                   3.00        Single           7.00
# 3             Basic                   3.00      Divorced           2.00
# 4             Basic                   4.00      Divorced           1.00
# ...             ...                    ...           ...            ...
# 4883         Deluxe                   4.00     Unmarried           2.00
# 4884          Basic                   3.00        Single           3.00
# 4885       Standard                   4.00       Married           7.00
# 4886          Basic                   3.00        Single           3.00
# 4887          Basic                   4.00     Unmarried           3.00
#
#       Passport  PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting  \
# 0            1                       2       1                      0.00
# 1            0                       3       1                      2.00
# 2            1                       3       0                      0.00
# 3            1                       5       1                      1.00
# 4            0                       5       1                      0.00
# ...        ...                     ...     ...                       ...
# 4883         1                       1       1                      1.00
# 4884         1                       3       1                      2.00
# 4885         0                       1       1                      3.00
# 4886         0                       5       0                      2.00
# 4887         1                       3       1                      2.00
#
#          Designation  MonthlyIncome
# 0            Manager       20993.00
# 1            Manager       20130.00
# 2          Executive       17090.00
# 3          Executive       17909.00
# 4          Executive       18468.00
# ...              ...            ...
# 4883         Manager       26576.00
# 4884       Executive       21212.00
# 4885  Senior Manager       31820.00
# 4886       Executive       20289.00
# 4887       Executive       24041.00
#
# [4888 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   object
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   object
#  13  NumberOfTrips             4748 non-null   float64
#  14  Passport                  4888 non-null   int64
#  15  PitchSatisfactionScore    4888 non-null   int64
#  16  OwnCar                    4888 non-null   int64
#  17  NumberOfChildrenVisiting  4822 non-null   float64
#  18  Designation               4888 non-null   object
#  19  MonthlyIncome             4655 non-null   float64
# dtypes: float64(6), int64(7), object(7)
# memory usage: 763.9+ KB

# %%
df.isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
df.nunique()
# Out:
# CustomerID                  4888
# ProdTaken                      2
# Age                           51
# TypeofContact                  2
# CityTier                       3
# DurationOfPitch               34
# Occupation                     4
# Gender                         3
# NumberOfPersonVisiting         5
# NumberOfFollowups              6
# ProductPitched                 5
# PreferredPropertyStar          3
# MaritalStatus                  4
# NumberOfTrips                 12
# Passport                       2
# PitchSatisfactionScore         5
# OwnCar                         2
# NumberOfChildrenVisiting       4
# Designation                    5
# MonthlyIncome               2475
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#       CustomerID  ProdTaken  Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41t     Self Enquiry         3             6.00
# 1         200001          0   49  Company Invited         1            14.00
# 2         200002          1   37     Self Enquiry         1             8.00
# 3         200003          0   33  Company Invited         1             9.00
# 4         200004          0  NaN     Self Enquiry         1             8.00
# ...          ...        ...  ...              ...       ...              ...
# 4883      204883          1   49     Self Enquiry         3             9.00
# 4884      204884          1   28  Company Invited         1            31.00
# 4885      204885          1   52     Self Enquiry         3            17.00
# 4886      204886          1   19     Self Enquiry         3            16.00
# 4887      204887          1   36     Self Enquiry         1            14.00
#
#           Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0           Salaried  Female                       3               3.00
# 1           Salaried    Male                       3               4.00
# 2        Free Lancer    Male                       3               4.00
# 3           Salaried  Female                       2               3.00
# 4     Small Business    Male                       2               3.00
# ...              ...     ...                     ...                ...
# 4883  Small Business    Male                       3               5.00
# 4884        Salaried    Male                       4               5.00
# 4885        Salaried  Female                       4               4.00
# 4886  Small Business    Male                       3               4.00
# 4887        Salaried    Male                       4               4.00
#
#      ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 0            Deluxe                   3.00        Single           1.00
# 1            Deluxe                   4.00      Divorced           2.00
# 2             Basic                   3.00        Single           7.00
# 3             Basic                   3.00      Divorced           2.00
# 4             Basic                   4.00      Divorced           1.00
# ...             ...                    ...           ...            ...
# 4883         Deluxe                   4.00     Unmarried           2.00
# 4884          Basic                   3.00        Single           3.00
# 4885       Standard                   4.00       Married           7.00
# 4886          Basic                   3.00        Single           3.00
# 4887          Basic                   4.00     Unmarried           3.00
#
#       Passport  PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting  \
# 0            1                       2       1                      0.00
# 1            0                       3       1                      2.00
# 2            1                       3       0                      0.00
# 3            1                       5       1                      1.00
# 4            0                       5       1                      0.00
# ...        ...                     ...     ...                       ...
# 4883         1                       1       1                      1.00
# 4884         1                       3       1                      2.00
# 4885         0                       1       1                      3.00
# 4886         0                       5       0                      2.00
# 4887         1                       3       1                      2.00
#
#          Designation  MonthlyIncome
# 0            Manager       20993.00
# 1            Manager       20130.00
# 2          Executive       17090.00
# 3          Executive       17909.00
# 4          Executive       18468.00
# ...              ...            ...
# 4883         Manager       26576.00
# 4884       Executive       21212.00
# 4885  Senior Manager       31820.00
# 4886       Executive       20289.00
# 4887       Executive       24041.00
#
# [4888 rows x 20 columns]

# %%
df.sort_values(by="Age", ascending=False)
# Out:
#       CustomerID  ProdTaken  Age    TypeofContact  CityTier  DurationOfPitch  \
# 58        200058          0  d31     Self Enquiry         1            13.00
# 4450      204450          0   61     Self Enquiry         3            23.00
# 2855      202855          0   61     Self Enquiry         1            14.00
# 4341      204341          0   61  Company Invited         3            35.00
# 3653      203653          0   61     Self Enquiry         1             7.00
# ...          ...        ...  ...              ...       ...              ...
# 2410      202410          1  NaN     Self Enquiry         1            30.00
# 2413      202413          1  NaN     Self Enquiry         3            21.00
# 2427      202427          1  NaN     Self Enquiry         3            22.00
# 2430      202430          1  NaN     Self Enquiry         1            14.00
# 2435      202435          1  NaN     Self Enquiry         2            26.00
#
#           Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 58          Salaried    Male                       2               3.00
# 4450  Small Business    Male                       3               4.00
# 2855        Salaried  Female                       3               4.00
# 4341  Small Business  Female                       4               5.00
# 3653  Small Business    Male                       4               6.00
# ...              ...     ...                     ...                ...
# 2410  Small Business    Male                       2               3.00
# 2413  Small Business    Male                       2               5.00
# 2427  Small Business    Male                       3               3.00
# 2430  Small Business  Female                       3               3.00
# 2435  Small Business  Female                       3               3.00
#
#      ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 58           Deluxe                   3.00       Married           4.00
# 4450         Deluxe                   5.00     Unmarried           2.00
# 2855           King                   5.00      Divorced           7.00
# 4341       Standard                   5.00       Married           6.00
# 3653       Standard                   3.00       Married           5.00
# ...             ...                    ...           ...            ...
# 2410          Basic                   4.00       Married           2.00
# 2413         Deluxe                   3.00       Married           7.00
# 2427       Standard                   3.00       Married           3.00
# 2430          Basic                   5.00       Married           2.00
# 2435          Basic                   4.00       Married           1.00
#
#       Passport  PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting  \
# 58           0                       3       1                      0.00
# 4450         0                       4       1                      2.00
# 2855         0                       5       0                      1.00
# 4341         0                       1       1                      1.00
# 3653         0                       5       0                      1.00
# ...        ...                     ...     ...                       ...
# 2410         1                       1       0                      0.00
# 2413         1                       1       0                      1.00
# 2427         0                       5       0                      1.00
# 2430         1                       3       0                      2.00
# 2435         1                       3       0                      1.00
#
#          Designation  MonthlyIncome
# 58           Manager       20915.00
# 4450         Manager       24083.00
# 2855              VP       38244.00
# 4341  Senior Manager       28944.00
# 3653  Senior Manager       29561.00
# ...              ...            ...
# 2410       Executive            NaN
# 2413         Manager       18423.00
# 2427  Senior Manager       18544.00
# 2430       Executive            NaN
# 2435       Executive       18669.00
#
# [4888 rows x 20 columns]

# %%
df["Age"]=df["Age"].str.replace(r'[^\d]','',regex=True)

# %%
df.sort_values(by="Age", ascending=False)
# Out:
#       CustomerID  ProdTaken  Age    TypeofContact  CityTier  DurationOfPitch  \
# 4341      204341          0   61  Company Invited         3            35.00
# 2871      202871          0   61  Company Invited         3            35.00
# 3653      203653          0   61     Self Enquiry         1             7.00
# 3323      203323          0   61     Self Enquiry         3            14.00
# 2855      202855          0   61     Self Enquiry         1            14.00
# ...          ...        ...  ...              ...       ...              ...
# 2410      202410          1  NaN     Self Enquiry         1            30.00
# 2413      202413          1  NaN     Self Enquiry         3            21.00
# 2427      202427          1  NaN     Self Enquiry         3            22.00
# 2430      202430          1  NaN     Self Enquiry         1            14.00
# 2435      202435          1  NaN     Self Enquiry         2            26.00
#
#           Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 4341  Small Business  Female                       4               5.00
# 2871  Small Business  Female                       4               5.00
# 3653  Small Business    Male                       4               6.00
# 3323  Small Business    Male                       3               2.00
# 2855        Salaried  Female                       3               4.00
# ...              ...     ...                     ...                ...
# 2410  Small Business    Male                       2               3.00
# 2413  Small Business    Male                       2               5.00
# 2427  Small Business    Male                       3               3.00
# 2430  Small Business  Female                       3               3.00
# 2435  Small Business  Female                       3               3.00
#
#      ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 4341       Standard                   5.00       Married           6.00
# 2871       Standard                   5.00      Divorced           6.00
# 3653       Standard                   3.00       Married           5.00
# 3323         Deluxe                   3.00       Married           2.00
# 2855           King                   5.00      Divorced           7.00
# ...             ...                    ...           ...            ...
# 2410          Basic                   4.00       Married           2.00
# 2413         Deluxe                   3.00       Married           7.00
# 2427       Standard                   3.00       Married           3.00
# 2430          Basic                   5.00       Married           2.00
# 2435          Basic                   4.00       Married           1.00
#
#       Passport  PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting  \
# 4341         0                       1       1                      1.00
# 2871         0                       2       1                      1.00
# 3653         0                       5       0                      1.00
# 3323         1                       5       0                      1.00
# 2855         0                       5       0                      1.00
# ...        ...                     ...     ...                       ...
# 2410         1                       1       0                      0.00
# 2413         1                       1       0                      1.00
# 2427         0                       5       0                      1.00
# 2430         1                       3       0                      2.00
# 2435         1                       3       0                      1.00
#
#          Designation  MonthlyIncome
# 4341  Senior Manager       28944.00
# 2871  Senior Manager       28944.00
# 3653  Senior Manager       29561.00
# 3323         Manager       23898.00
# 2855              VP       38244.00
# ...              ...            ...
# 2410       Executive            NaN
# 2413         Manager       18423.00
# 2427  Senior Manager       18544.00
# 2430       Executive            NaN
# 2435       Executive       18669.00
#
# [4888 rows x 20 columns]

# %%
df.corr(numeric_only=True)
# Out:
#                           CustomerID  ProdTaken  CityTier  DurationOfPitch  \
# CustomerID                      1.00       0.06      0.01             0.06
# ProdTaken                       0.06       1.00      0.09             0.08
# CityTier                        0.01       0.09      1.00             0.02
# DurationOfPitch                 0.06       0.08      0.02             1.00
# NumberOfPersonVisiting          0.60       0.01     -0.00             0.07
# NumberOfFollowups               0.43       0.11      0.02             0.01
# PreferredPropertyStar           0.01       0.10     -0.01            -0.01
# NumberOfTrips                   0.22       0.02     -0.03             0.01
# Passport                        0.01       0.26      0.00             0.03
# PitchSatisfactionScore         -0.04       0.05     -0.04            -0.00
# OwnCar                          0.00      -0.01      0.00            -0.00
# NumberOfChildrenVisiting        0.51       0.01      0.00             0.03
# MonthlyIncome                   0.28      -0.13      0.05            -0.01
#
#                           NumberOfPersonVisiting  NumberOfFollowups  \
# CustomerID                                  0.60               0.43
# ProdTaken                                   0.01               0.11
# CityTier                                   -0.00               0.02
# DurationOfPitch                             0.07               0.01
# NumberOfPersonVisiting                      1.00               0.33
# NumberOfFollowups                           0.33               1.00
# PreferredPropertyStar                       0.03              -0.02
# NumberOfTrips                               0.20               0.14
# Passport                                    0.01               0.00
# PitchSatisfactionScore                     -0.02               0.00
# OwnCar                                      0.01               0.01
# NumberOfChildrenVisiting                    0.61               0.29
# MonthlyIncome                               0.20               0.18
#
#                           PreferredPropertyStar  NumberOfTrips  Passport  \
# CustomerID                                 0.01           0.22      0.01
# ProdTaken                                  0.10           0.02      0.26
# CityTier                                  -0.01          -0.03      0.00
# DurationOfPitch                           -0.01           0.01      0.03
# NumberOfPersonVisiting                     0.03           0.20      0.01
# NumberOfFollowups                         -0.02           0.14      0.00
# PreferredPropertyStar                      1.00           0.01      0.00
# NumberOfTrips                              0.01           1.00      0.01
# Passport                                   0.00           0.01      1.00
# PitchSatisfactionScore                    -0.02          -0.00      0.00
# OwnCar                                     0.02          -0.01     -0.02
# NumberOfChildrenVisiting                   0.04           0.17      0.02
# MonthlyIncome                              0.01           0.14      0.00
#
#                           PitchSatisfactionScore  OwnCar  \
# CustomerID                                 -0.04    0.00
# ProdTaken                                   0.05   -0.01
# CityTier                                   -0.04    0.00
# DurationOfPitch                            -0.00   -0.00
# NumberOfPersonVisiting                     -0.02    0.01
# NumberOfFollowups                           0.00    0.01
# PreferredPropertyStar                      -0.02    0.02
# NumberOfTrips                              -0.00   -0.01
# Passport                                    0.00   -0.02
# PitchSatisfactionScore                      1.00    0.07
# OwnCar                                      0.07    1.00
# NumberOfChildrenVisiting                    0.00    0.03
# MonthlyIncome                               0.03    0.08
#
#                           NumberOfChildrenVisiting  MonthlyIncome
# CustomerID                                    0.51           0.28
# ProdTaken                                     0.01          -0.13
# CityTier                                      0.00           0.05
# DurationOfPitch                               0.03          -0.01
# NumberOfPersonVisiting                        0.61           0.20
# NumberOfFollowups                             0.29           0.18
# PreferredPropertyStar                         0.04           0.01
# NumberOfTrips                                 0.17           0.14
# Passport                                      0.02           0.00
# PitchSatisfactionScore                        0.00           0.03
# OwnCar                                        0.03           0.08
# NumberOfChildrenVisiting                      1.00           0.20
# MonthlyIncome                                 0.20           1.00

# %%
import seaborn as sns

# %%
mean1=df['Age'].mean()
df['Age']=df['Age'].fillna(value=mean1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 mean1=df['Age'].mean()
#       2 df['Age']=df['Age'].fillna(value=mean1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12373 nv.validate_func(name, (), kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6452     # GH#47500 - change to TypeError to match other methods
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:719, in nanmean(values, axis, skipna, mask)
#     716     dtype_count = dtype
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 719 the_sum = values.sum(axis, dtype=dtype_sum)
#     720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File ~\anaconda3\Lib\site-packages\numpy\core\_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str
